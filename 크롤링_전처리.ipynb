# %%
import pandas as pd

# %% [markdown]
# # 전처리 할 파일 및 크롤링 실패한 url 불러오기

# %%
df_prefer_data_eng = pd.read_csv("C:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\data\prefer_bigdata_eng.csv")
df_prefer_data_analy = pd.read_csv("C:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\data\prefer_data_analy.csv")
df_prefer_data_sci = pd.read_csv("C:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\data\prefer_data_sci.csv")

# %%
df_loc_data_eng = pd.read_csv("C:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\data\loc_bigdata_eng.csv")
df_loc_data_analy = pd.read_csv("C:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\data\loc_data_analy.csv")
df_loc_data_sci = pd.read_csv("C:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\data\prefer_data_sci.csv")

# %%
df_tool_data_eng = pd.read_csv("C:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\data\\tool_bigdata_eng.csv")
df_tool_data_analy = pd.read_csv("C:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\data\\tool_data_analy.csv")
df_tool_data_sci = pd.read_csv("C:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\data\\tool_data_sci.csv")

# %%
df_fail_data_eng = pd.read_csv("C:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\data\\fail_url_bigdata_eng.csv")
df_fail_data_analy = pd.read_csv("C:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\data\\fail_url_data_analy.csv")
df_fail_data_sci = pd.read_csv("C:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\data\\fail_url_data_sci.csv")

# %% [markdown]
# - 불러오기 실패한 url 갯수 확인

# %%
df_fail_data_eng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  166 non-null    int64
#  1   0           0 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 2.7 KB

# %%
df_fail_data_analy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  173 non-null    int64
#  1   0           2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 2.8+ KB

# %%
df_fail_data_sci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  236 non-null    int64
#  1   0           2 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 3.8+ KB

# %% [markdown]
# - tool 확인

# %%
df_tool_data_eng = df_tool_data_eng.drop(columns = 'Unnamed: 0') # csv저장시 index = False 깜빡함.
df_tool_data_eng = df_tool_data_eng.dropna()
df_tool_data_eng
# Out:
#                                                      0
# 0                         Git\nReact\nHTML\nJavaScript
# 4                                        MySQL\nPython
# 6                        Linux\n컴파일러\n알고리즘 개발\n네트워크 개발
# 7                                    HTML\nCSS 자바 스크립트
# 8                                               Python
# ..                                                 ...
# 157  MySQL\nOracle\nReact\nJava\nJavaScript\nKotlin...
# 159               Git\nMySQL\nRedis\nNode.js\nAWS\nGCP
# 160                           Git\nPython\nAWS\nDocker
# 161  MySQL\nOracle\nReact\nJava\nJavaScript\nKotlin...
# 163  MySQL\nOracle\nReact\nJava\nJavaScript\nKotlin...
#
# [112 rows x 1 columns]

# %%
df_tool_data_eng.columns = ['tool']

# %% [markdown]
# # 개행문자 제거

# %%
df_tool_data_eng = df_tool_data_eng['tool'].str.replace("\n", ", ").str.replace("\t", "") # \n, \t제거
df_tool_data_eng
# Out:
# 0                           Git, React, HTML, JavaScript
# 4                                          MySQL, Python
# 6                          Linux, 컴파일러, 알고리즘 개발, 네트워크 개발
# 7                                      HTML, CSS 자바 스크립트
# 8                                                 Python
#                              ...
# 157    MySQL, Oracle, React, Java, JavaScript, Kotlin...
# 159                 Git, MySQL, Redis, Node.js, AWS, GCP
# 160                             Git, Python, AWS, Docker
# 161    MySQL, Oracle, React, Java, JavaScript, Kotlin...
# 163    MySQL, Oracle, React, Java, JavaScript, Kotlin...
# Name: tool, Length: 112, dtype: object

# %%
df_tool_data_eng
# Out:
# 0                           Git, React, HTML, JavaScript
# 4                                          MySQL, Python
# 6                          Linux, 컴파일러, 알고리즘 개발, 네트워크 개발
# 7                                      HTML, CSS 자바 스크립트
# 8                                                 Python
#                              ...
# 157    MySQL, Oracle, React, Java, JavaScript, Kotlin...
# 159                 Git, MySQL, Redis, Node.js, AWS, GCP
# 160                             Git, Python, AWS, Docker
# 161    MySQL, Oracle, React, Java, JavaScript, Kotlin...
# 163    MySQL, Oracle, React, Java, JavaScript, Kotlin...
# Name: 우대사항, Length: 112, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # 형태소 분석

# %%
# 형태소 분석기 별 테스트
from konlpy.tag import Okt
from konlpy.tag import Hannanum 
from konlpy.tag import Kkma 
from konlpy.tag import Komoran 
from konlpy.tag import Mecab

# %%
# 리스트로 변환하여 처리하는 게 편할듯 함..
prefer_list = df_prefer.to_list()
prefer_list
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
prefer_list[0]
# Out:
# nan

# %%
# 1번째 데이터만 형태소 분석 결과 : '컴퓨터 비전'이 아닌 '컴퓨터', '비전'이 따로 분리... 
okt = Okt()
print(okt.morphs(prefer_list[0]))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\Data_Engineer_Study\멀캠_PJT_2\Crolling_wanted\multi_finalproject\크롤링_전처리.ipynb Cell 22 line 3
#       <a href='vscode-notebook-cell:/c%3A/Data_Engineer_Study/%EB%A9%80%EC%BA%A0_PJT_2/Crolling_wanted/multi_finalproject/%ED%81%AC%EB%A1%A4%EB%A7%81_%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> # 1번째 데이터만 형태소 분석 결과 : '컴퓨터 비전'이 아닌 '컴퓨터', '비전'이 따로 분리...
#       <a href='vscode-notebook-cell:/c%3A/Data_Engineer_Study/%EB%A9%80%EC%BA%A0_PJT_2/Crolling_wanted/multi_finalproject/%ED%81%AC%EB%A1%A4%EB%A7%81_%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> okt = Okt()
# ...

# %%
# import webbrowser
# import time
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
# from selenium.webdriver.common.alert import Alert

# %%
# # 챗GPT에 위 문장을 입력, 주요 키워드를 알려달라고 한 후 결과 크롤링?....-> 로그인 자체가 안됨... ㅋㅋ
# browser = webdriver.Chrome()
# browser.get("https://chat.openai.com/c/6aca10a4-cd72-4620-84cd-01262e793e07")

# %%
# 나머지 형태소 분석기 테스트
hannanum = Hannanum()
kkma = Kkma()
komoran = Komoran()

# %% [markdown]
# - hannanum Class

# %%
print(hannanum.analyze(prefer_list[0])) # 다양한 형태로 반환
print(hannanum.morphs(prefer_list[0])) # 형태소 반환
print(hannanum.nouns(prefer_list[0])) # 명사 반환
print(hannanum.pos(prefer_list[0])) # 품사 정보 부착하여 반환
# Out:
# [[[('•', 'ncn')], [('•', 'nqq')]], [[('컴퓨터', 'ncn')]], [[('비전', 'ncn')], [('비전', 'ncpa')], [('비', 'ncn'), ('전', 'xsnx')], [('비', 'xp'), ('전', 'ncn')]], [[('관련', 'ncn')], [('관련', 'ncpa')]], [[('학회', 'ncn'), ('에', 'jca')]], [[('제1저', 'ncn'), ('이', 'jp'), ('자', 'ecc')], [('제1저', 'ncn'), ('이', 'jp'), ('자', 'ecs')], [('제1저', 'ncn'), ('이', 'jp'), ('자', 'ef')], [('제1저자', 'ncn')], [('제1저', 'nqq'), ('이', 'jp'), ('자', 'ecc')], [('제1저', 'nqq'), ('이', 'jp'), ('자', 'ecs')], [('제1저', 'nqq'), ('이', 'jp'), ('자', 'ef')], [('제1저자', 'nqq')]], [[('혹은', 'maj')], [('혹', 'mag'), ('은', 'jxc')], [('혹', 'ncn'), ('은', 'jxc')]], [[('교신', 'ncn'), ('저자', 'ncn'), ('로', 'jca')]], [[('논문', 'ncn')]], [[('게재', 'ncpa')]], [[('•', 'ncn')], [('•', 'nqq')]], [[('문제', 'ncn'), ('를', 'jco')], [('문제', 'ncpa'), ('를', 'jco')], [('문제', 'ncps'), ('를', 'jco')]], [[('찾', 'pvg'), ('고', 'ecc')], [('찾', 'pvg'), ('고', 'ecs')], [('찾', 'pvg'), ('고', 'ecx')]], [[('해결', 'ncpa'), ('하', 'xsva'), ('는', 'etm')], [('해결', 'ncpa'), ('하', 'xsva'),
# ...

# %% [markdown]
# - Kkma Class

# %%
print(kkma.morphs(prefer_list[0])) # 
print(kkma.nouns(prefer_list[0])) # 
print(kkma.pos(prefer_list[0])) # 
print(kkma.sentences(prefer_list[0])) #
# Out:
# ['•', '컴퓨터', '비전', '관련', '학회', '에', '저', '의', '1', '저', '자', '혹', '은', '교', '신저', '자로', '논문', '게재', '•', '문제', '를', '찾', '고', '해결', '하', '는', '과정', '에서', '성취감', '을', '느끼', '시', '는', '분', '•', '다양', '하', 'ㄴ', '영상', '또는', '이미지', '에', '대하', '여', '딥', '러닝', '을', '활용', '하', 'ㄴ', '연구', '경력', '•', 'unsupervised', '또는', 'self', '/', 'semi', '/', 'weakly', 'supervised', '딥', '러닝', '모델', '개발', '을', '하', 'ㄹ', '수', '있', '는', '분']
# ['컴퓨터', '비전', '관련', '학회', '저', '1', '혹', '교', '교신저자로', '신저', '자로', '논문', '게재', '문제', '해결', '과정', '성취감', '분', '다양', '영상', '이미지', '딥', '딥러닝', '러닝', '활용', '연구', '경력', '모델', '개발', '수', '분']
# ...
